# %% [markdown]
# ### Catalog Declaration

# %%
# %sql
CREATE CATALOG IF NOT EXISTS fmgs;
USE CATALOG fmgs;

# %% [markdown]
# ### Schema Declaration

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS fmgs.bronze;
CREATE SCHEMA IF NOT EXISTS fmgs.silver;
CREATE SCHEMA IF NOT EXISTS fmgs.gold;

# %%
# %sql
show databases from fmgs;
